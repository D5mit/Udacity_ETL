# %% [markdown]
# # Machine Learning Workflow
# Complete the steps below to complete the machine learning workflow for this classifier.

# %%
import nltk
nltk.download(['punkt', 'wordnet'])
# Out:
# [nltk_data] Downloading package punkt to /Users/d5mit/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/d5mit/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import re
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split 
from sklearn.feature_extraction.text import TfidfTransformer
import numpy as np
from sklearn.metrics import confusion_matrix

# %%
url_regex = 'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'

def load_data():
    df = pd.read_csv('corporate_messaging.csv', encoding='latin-1')
    df = df[(df["category:confidence"] == 1) & (df['category'] != 'Exclude')]
    X = df.text.values
    y = df.category.values
    return X, y

def tokenize(text):
    detected_urls = re.findall(url_regex, text)
    for url in detected_urls:
        text = text.replace(url, "urlplaceholder")

    tokens = word_tokenize(text)
    lemmatizer = WordNetLemmatizer()

    clean_tokens = []
    for tok in tokens:
        clean_tok = lemmatizer.lemmatize(tok).lower().strip()
        clean_tokens.append(clean_tok)

    return clean_tokens

def display_results(y_test, y_pred):
    labels = np.unique(y_pred)
    confusion_mat = confusion_matrix(y_test, y_pred, labels=labels)
    accuracy = (y_pred == y_test).mean()

    print("Labels:", labels)
    print("Confusion Matrix:\n", confusion_mat)
    print("Accuracy:", accuracy)

# %% [markdown]
# ### Step 1: Load data and perform a train test split

# %%
# load data
X, y = load_data()

# perform train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# ### Step 2: Train classifier
# * Fit and transform the training data with `CountVectorizer`. Hint: You can include your tokenize function in the `tokenizer` keyword argument!
# * Fit and transform these word counts with `TfidfTransformer`.
# * Fit a classifier to these tfidf values.

# %%
# Instantiate transformers and classifier
vect = CountVectorizer(tokenizer=tokenize)

# initialize tf-idf transformer object
tfidf = TfidfTransformer(smooth_idf=False)

# Fit a classifier to these tfidf values.
clf = RandomForestClassifier()

# Transform test data

print(X_train)
X_train_counts = vect.fit_transform(X_train)
print(X_train_counts)
X_train_tfidf = tfidf.fit_transform(X_train_counts)
print(X_train_tfidf)
clf.fit(X_train_tfidf, y_train)
# Out:
# ['Merck Fdn proud to support #mhealth texts/apps study improving diabetes outcomes. Learn more: http://t.co/tX8jSXa8qQ  via @Health_Affairs'
#  'Z Bhutta  Many developing countries are facing problem of increasing life expectancy but not necessarily improved quality of life  #NINS2013'
#  "Citi's strategy remains the right one: Corbat:  http://t.co/pCda2ioJua #Citigroup #BRK"
#  ...
#  '\x89ÛÏMerck has built a reputation for discovering and developing breakthrough therapeutics.\x89Û\x9d \x89ÛÒ R. Perlmutter #MerckBiz14'
#  'See how we work with coffee cooperatives to help improve #sustainability of production in Colombia #CSV2011 http://youtu.be/DEy4-vCYPP8'
#  'RT @atelierstat: Brazilian #Internet users spend 36% of their time on the internet on#SocialNetworks http://t.co/WLnHlHES5T  cc @comScore']
#   (0, 3059)	1
#   (0, 1941)	1
#   (0, 3761)	1
#   (0, 4604)	1
#   (0, 4465)	1
#   (0, 1)	1
#   (0, 3077)	1
#   (0, 4546)	1
#   (0, 4437)	1
#   (0, 2504)	1
#   (0, 1495)	1
#   (0, 3429)	1
#   (0, 49)	1
#   (0, 2815)	1
#   (0, 3154)	1
#   (0, 313)	1
#   (0, 4768)	1
#   (0, 4814)	1
#   (0, 316)	1
#   (0, 2332)	1
#   (1, 1)	1
#   (1, 5093)	1
#   (1, 750)	1
#   (1, 2985)	1
#   (1, 1489)	1
#   :	:
#   (1608, 4478)	1
#   (1608, 1157)	1
#   (1608, 3722)	1
#   (1608, 1173)	1
#   (1608, 1285)	1
#   (1609, 1)	2
#   (1609, 313)	1
#   (1609, 4768)	1
#   (1609, 316)	2
#   (1609, 3366)	1
#   (1609, 4556)	1
#   (1609, 3382)	2
#   (1609, 211)	1
#   (1609, 3)	1
#   (1609, 4046)	1
#   (1609, 975)	1
#   (1609, 4599)	1
#   (1609, 4561)	1
#   (1609, 846)	1
#   (1609, 4340)	1
#   (1609, 607)	1
#   (1609, 2588)	2
#   (1609, 4778)	1
#   (1609, 4297)	1
#   (1609, 1221)	1
#   (0, 4814)	0.21063696006081364
#   (0, 4768)	0.05445153469116114
#   (0, 4604)	0.08160206070084837
#   (0, 4546)	0.3544153610190459
#   (0, 4465)	0.19076855412181654
#   (0, 4437)	0.21355348727954948
#   (0, 3761)	0.2092508398907195
#   (0, 3429)	0.30797385809733907
#   (0, 3154)	0.14148887966220053
#   (0, 3077)	0.3251140350251653
#   (0, 3059)	0.20412056722466593
#   (0, 2815)	0.18820577689798934
#   (0, 2504)	0.2346472798196962
#   (0, 2332)	0.3544153610190459
#   (0, 1941)	0.3544153610190459
#   (0, 1495)	0.24598757051709003
#   (0, 316)	0.09625392935705783
#   (0, 313)	0.07958713786553913
#   (0, 49)	0.1029748053491846
#   (0, 1)	0.06300066901550595
#   (1, 5093)	0.26071286131437754
#   (1, 3798)	0.21762776256578092
#   (1, 3715)	0.20558684312898146
#   (1, 3366)	0.1645780623949281
#   (1, 3319)	0.17713966223426525
#   :	:
#   (1608, 1346)	0.30577685581639746
#   (1608, 1285)	0.38011490909037526
#   (1608, 1173)	0.34585655766137813
#   (1608, 1157)	0.30577685581639746
#   (1608, 1)	0.1473175009107695
#   (1609, 4778)	0.27111547890741583
#   (1609, 4768)	0.04165353855597864
#   (1609, 4599)	0.1670257653913564
#   (1609, 4561)	0.14801833892105234
#   (1609, 4556)	0.06784335024531861
#   (1609, 4340)	0.24870097913344485
#   (1609, 4297)	0.27111547890741583
#   (1609, 4046)	0.12822215901443393
#   (1609, 3382)	0.204606661725967
#   (1609, 3366)	0.07435927107154547
#   (1609, 2588)	0.5422309578148317
#   (1609, 1221)	0.27111547890741583
#   (1609, 975)	0.22628647935947382
#   (1609, 846)	0.24870097913344485
#   (1609, 607)	0.27111547890741583
#   (1609, 316)	0.14726184598391004
#   (1609, 313)	0.060881404618708466
#   (1609, 211)	0.24870097913344485
#   (1609, 3)	0.14334297413360697
#   (1609, 1)	0.09638666056976354
# RandomForestClassifier()

# %%
vect.vocabulary_
# Out:
# {'merck': 3059,
#  'fdn': 1941,
#  'proud': 3761,
#  'to': 4604,
#  'support': 4465,
#  '#': 1,
#  'mhealth': 3077,
#  'texts/apps': 4546,
#  'study': 4437,
#  'improving': 2504,
#  'diabetes': 1495,
#  'outcome': 3429,
#  '.': 49,
#  'learn': 2815,
#  'more': 3154,
#  ':': 313,
#  'urlplaceholder': 4768,
#  'via': 4814,
#  '@': 316,
#  'health_affairs': 2332,
#  'z': 5093,
#  'bhutta': 750,
#  'many': 2985,
#  'developing': 1489,
#  'country': 1313,
#  'are': 565,
#  'facing': 1894,
#  'problem': 3715,
#  'of': 3366,
#  'increasing': 2517,
#  'life': 2859,
#  'expectancy': 1857,
#  'but': 897,
#  'not': 3319,
#  'necessarily': 3242,
#  'improved': 2502,
#  'quality': 3798,
#  'nins2013': 3300,
#  'citi': 1076,
#  "'s": 22,
#  'strategy': 4415,
#  'remains': 3936,
#  'the': 4556,
#  'right': 4012,
#  'one': 3386,
#  'corbat': 1291,
#  'citigroup': 1087,
#  'brk': 869,
#  'a': 323,
#  'live': 2890,
#  'webcast': 4924,
#  'from': 2081,
#  '2014': 158,
#  'nestle': 3262,
#  'investor': 2604,
#  'seminar': 4167,
#  'take': 4496,
#  'place': 3590,
#  'today': 4606,
#  'at': 605,
#  '4.40pm': 220,
#  'cet': 1000,
#  'launch': 2799,
#  'luxury': 2941,
#  'dog': 1566,
#  'food': 2020,
#  'in': 2505,
#  'brazil': 844,
#  'purina': 3783,
#  'pfizer': 3550,
#  'sponsored': 4347,
#  'symposium': 4484,
#  'discus': 1538,
#  'present': 3675,
#  '&': 4,
#  'amp': 502,
#  'future': 2112,
#  'outlook': 3434,
#  'mrcc': 3182,
#  'treatment': 4667,
#  'option': 3411,
#  'ecc2013': 1648,
#  'debtidwell': 1429,
#  'our': 3424,
#  'nan': 3219,
#  'h.a': 2273,
#  '1': 60,
#  'gold': 2199,
#  'infant': 2536,
#  'formula': 2045,
#  'is': 2626,
#  'safe': 4066,
#  'read': 3839,
#  'on': 3382,
#  'website': 4926,
#  'vassiliou': 4800,
#  'showing': 4224,
#  'that': 4554,
#  'stakeholder': 4370,
#  'can': 935,
#  'work': 5008,
#  'together': 4609,
#  'bring': 862,
#  'about': 335,
#  'change': 1015,
#  'employment4youth': 1713,
#  'it\x89ûªs': 2645,
#  'national': 3229,
#  'immunization': 2487,
#  'awareness': 644,
#  'month': 3150,
#  'teen': 4535,
#  'get': 2155,
#  'health': 2330,
#  'tip': 4601,
#  'vaccine': 4790,
#  'preventable': 3688,
#  'disease': 1542,
#  'keith': 2728,
#  'godfrey': 2197,
#  ',': 37,
#  'uni': 4746,
#  'southhampton': 4322,
#  'up': 4759,
#  'now': 3328,
#  '-': 38,
#  'talking': 4501,
#  'how': 2428,
#  'poor': 3623,
#  'start': 4379,
#  'child': 1046,
#  'have': 2316,
#  'lasting': 2790,
#  'effect': 1666,
#  'between': 744,
#  '2004-2010': 145,
#  'we': 4914,
#  'reduced': 3898,
#  'water': 4905,
#  'use': 4775,
#  'european': 1809,
#  'manufacturing': 2984,
#  'operation': 3403,
#  'by': 905,
#  '36': 211,
#  '%': 3,
#  'worldwaterday': 5029,
#  'international': 2587,
#  'maternal': 3004,
#  'day': 1416,
#  'rt': 4046,
#  'if': 2475,
#  'you': 5082,
#  'agree': 441,
#  'no': 3304,
#  'woman': 4999,
#  'should': 4220,
#  'die': 1506,
#  'giving': 2176,
#  'intlmhday': 2592,
#  'merckformothers': 3063,
#  'valentin': 4792,
#  'marinov': 2993,
#  'g10': 2116,
#  'fx': 2113,
#  'strategist': 4414,
#  'will': 4979,
#  'be': 698,
#  'cnbc': 1143,
#  '13:45': 103,
#  'gmt': 2191,
#  'talk': 4500,
#  'likely': 2870,
#  'response': 3974,
#  'cross': 1340,
#  'u': 4709,
#  'non-farm': 3310,
#  'payroll': 3519,
#  'data': 1410,
#  'big': 753,
#  'bank': 664,
#  'accused': 356,
#  'housing': 2427,
#  'discrimination': 1537,
#  'again': 426,
#  'miami': 3079,
#  'dec': 1431,
#  '19': 124,
#  '(': 30,
#  'reuters': 3989,
#  ')': 31,
#  'ha': 2279,
#  'sued': 4448,
#  '...': 51,
#  'appoints': 549,
#  'mikael': 3098,
#  'dolsten': 1570,
#  'president': 3680,
#  'worldwide': 5030,
#  'research': 3965,
#  'and': 511,
#  'development': 1490,
#  'produce': 3718,
#  'healthcare': 2333,
#  'resource': 3971,
#  'guide': 2262,
#  'for': 2031,
#  'resident': 3968,
#  'bronx': 875,
#  'nyc': 3349,
#  'exclusive': 1843,
#  'fed': 1946,
#  'push': 3786,
#  'ignore': 2478,
#  'rival': 4022,
#  'when': 4962,
#  'setting': 4190,
#  'bonus': 815,
#  'federal': 1947,
#  'reserve': 3967,
#  'want': 4892,
#  'improve': 2501,
#  'your': 5085,
#  '?': 315,
#  'importance': 2497,
#  'following': 2017,
#  'prescribed': 3673,
#  'plan': 3592,
#  'own': 3451,
#  'sachin': 4065,
#  'jain': 2659,
#  'modern': 3138,
#  'medicine': 3040,
#  'requires': 3962,
#  'collaborating': 1163,
#  'across': 365,
#  'boundary': 835,
#  'do': 1561,
#  'communicate': 1194,
#  'online': 3389,
#  'wimaccelerator': 4982,
#  'co-founder': 1148,
#  'jkhoey': 2679,
#  'host': 2421,
#  'soc': 4289,
#  'financial': 1983,
#  'biz': 774,
#  'conversation': 1276,
#  'register': 3913,
#  'developed': 1488,
#  'display': 1545,
#  'higher': 2377,
#  'level': 2846,
#  'uncertainty': 4723,
#  'next': 3285,
#  'generation': 2148,
#  'looking': 2912,
#  'after': 425,
#  'wealth': 4916,
#  'australia': 624,
#  '59': 253,
#  '61': 264,
#  'keep': 2726,
#  'an': 504,
#  'eye': 1880,
#  'out': 3427,
#  'tomorrow': 4612,
#  'first': 1998,
#  'healthybytes': 2340,
#  'video': 4816,
#  '!': 0,
#  'great': 2222,
#  'job': 2680,
#  'those': 4583,
#  'who': 4969,
#  'presented': 3677,
#  'today\x89ûªs': 4607,
#  'bdi': 696,
#  'session': 4188,
#  'digitas_health': 1516,
#  'shwen': 4227,
#  'jonmrich': 2693,
#  'raykerins': 3831,
#  'pharmaguy': 3559,
#  'mario': 2994,
#  'nacinovich': 3215,
#  'osteoporosis': 3420,
#  'foundation': 2055,
#  'iofbonehealth': 2612,
#  'rewarded': 4003,
#  'danone': 1394,
#  'it': 2637,
#  'program': 3732,
#  'sensitize': 4175,
#  'employee': 1709,
#  'bonehealth': 814,
#  'partner': 3493,
#  'with': 4994,
#  'pet': 3545,
#  'exercise': 1847,
#  'project': 3736,
#  'slim': 4270,
#  'down': 1588,
#  'nestlì©': 3269,
#  'jennycraig': 2672,
#  'diversified': 1553,
#  'fund': 2103,
#  'may': 3015,
#  'seem': 4156,
#  'like': 2868,
#  'free': 2069,
#  'lunch': 2936,
#  'le': 2808,
#  'transparent': 4661,
#  'say': 4106,
#  'michael': 3080,
#  'dick': 1503,
#  'eal_awards': 1630,
#  'good': 2204,
#  'ed': 1655,
#  'agrees': 443,
#  'buy': 898,
#  'back': 651,
#  'security': 4148,
#  'hawaii': 2319,
#  'ahead': 446,
#  'schedule': 4113,
#  'hero': 2372,
#  'feature': 1943,
#  'spotlighting': 4354,
#  'volunteer': 4849,
#  'check': 1031,
#  'inc.': 2507,
#  'announces': 522,
#  'appointment': 548,
#  'edward': 1665,
#  'skyler': 4263,
#  'executive': 1846,
#  'vice': 4815,
#  'global': 2181,
#  'public': 3777,
#  'affair': 410,
#  'li': 2854,
#  'ka-shing': 2720,
#  'docker': 1563,
#  'accept': 344,
#  'pay': 3517,
#  'offer': 3368,
#  'end': 1729,
#  'longest': 2909,
#  'strike': 4425,
#  'port': 3631,
#  'worker': 5014,
#  'billionaire': 763,
#  'k': 2718,
#  '[': 317,
#  'blogpost': 791,
#  ']': 318,
#  'nutrigo': 3340,
#  'curb': 1354,
#  'malnutrition': 2967,
#  'among': 500,
#  'chinese': 1054,
#  'baby': 650,
#  'rural': 4055,
#  'area': 566,
#  'cc': 975,
#  'danonecommunity': 1399,
#  'latinastylemag': 2796,
#  'initiative': 2554,
#  'provide': 3764,
#  'tool': 4617,
#  'hispanic': 2394,
#  'community': 1199,
#  'see': 4150,
#  'here': 2371,
#  'pfe': 3548,
#  'center': 988,
#  'therapeutic': 4567,
#  'innovation': 2559,
#  'network': 3273,
#  'partnership': 3497,
#  'w/university': 4882,
#  'california': 920,
#  'political_hawk': 3620,
#  'detail': 1482,
#  'blog': 790,
#  'downto_earth_': 1590,
#  'empowerment': 1716,
#  'key': 2735,
#  'challenge': 1010,
#  '\x89û_': 5098,
#  'socent': 4290,
#  'this': 4582,
#  'week\x89ûªs': 4931,
#  'human-tech': 2443,
#  'post': 3642,
#  'vrulon': 4857,
#  'look': 2911,
#  'travel': 4662,
#  'through': 4590,
#  'lens': 2833,
#  'science': 4122,
#  'fiction': 1968,
#  'scifi': 4128,
#  'civic': 1107,
#  'decision': 1434,
#  'based': 678,
#  '+': 33,
#  'human': 2441,
#  'experience': 1861,
#  'expertise': 1865,
#  'ncs2014': 3238,
#  'citiforcities': 1085,
#  'joseph': 2694,
#  'jimenez': 2678,
#  '100': 74,
#  'million': 3107,
#  'people': 3529,
#  'year': 5065,
#  'pushed': 3787,
#  'into': 2593,
#  'poverty': 3646,
#  'because': 703,
#  'they': 4574,
#  'wef2014': 4933,
#  'novartis': 3325,
#  'a1': 325,
#  'fellowship': 1956,
#  'help': 2363,
#  'ngo': 3289,
#  'solve': 4306,
#  'issue': 2635,
#  'while': 4966,
#  'fellow': 1955,
#  'gain': 2117,
#  'local': 2900,
#  'learning': 2817,
#  'whyprobono': 4976,
#  'aim': 449,
#  'well-being': 4941,
#  'mom': 3141,
#  'everywhere': 1823,
#  'mother': 3166,
#  'made': 2949,
#  'difference': 1509,
#  'peru': 3543,
#  'journalism': 2699,
#  'award': 639,
#  'excellenceì¢\x89ââ\x89ûï': 1836,
#  'recognizing': 3871,
#  'article': 581,
#  'impact': 2491,
#  ';': 314,
#  'add': 380,
#  'value': 4793,
#  'corporate': 1299,
#  'responsibility': 3975,
#  '\x89ûò': 5134,
#  'investment': 2603,
#  'united': 4751,
#  'negro': 3252,
#  'college': 1170,
#  'fund/merck': 2104,
#  '$': 2,
#  '37.5': 213,
#  'since': 4246,
#  '1996': 134,
#  'bewell': 746,
#  'art14_london': 579,
#  'private': 3706,
#  'museum': 3202,
#  'summit': 4457,
#  'gather': 2129,
#  'super-collectors': 4460,
#  'spearsmagazine': 4332,
#  'june': 2713,
#  'migraine': 3096,
#  'show': 4222,
#  '50': 242,
#  'sufferer': 4451,
#  'remain': 3934,
#  'undiagnosed': 4739,
#  'www.migrainesatwork.com': 5049,
#  '1300': 101,
#  'citivolunteers': 1093,
#  'helping': 2366,
#  'repaint': 3947,
#  'school': 4119,
#  'classroom': 1116,
#  'unsustainably': 4756,
#  'wellian': 4942,
#  'wiranto': 4988,
#  'asia': 587,
#  'europe': 1808,
#  '29/02/12': 182,
#  '10am': 83,
#  'hk/sg': 2399,
#  'time': 4599,
#  'iagg2013': 2461,
#  'panel': 3478,
#  'note': 3320,
#  'prevention': 3692,
#  'adherence': 387,
#  'active': 371,
#  'aging': 436,
#  'population': 3629,
#  'letsgetold': 2840,
#  'recruited': 3884,
#  'personnel': 3541,
#  'regulatory': 3915,
#  'discovery': 1535,
#  'group': 2244,
#  '-r.': 48,
#  'perlmutter': 3537,
#  'mrk': 3184,
#  '2nd': 187,
#  'report': 3953,
#  'entrepreneur': 1762,
#  'index': 2522,
#  'series': 4180,
#  'resurgence': 3980,
#  'entrepreneurial': 1763,
#  'activity': 375,
#  'h2': 2277,
#  '2011': 153,
#  '2012': 154,
#  'designer': 1476,
#  'client': 1124,
#  'lose': 2917,
#  'due': 1614,
#  'manual': 2979,
#  'feedback': 1950,
#  'loop': 2913,
#  'conceptbox': 1223,
#  'enables': 1721,
#  'sharing': 4205,
#  'collaboration': 1164,
#  'real-time': 3846,
#  'seedcamplive': 4152,
#  '\x89ûï': 5101,
#  'sanitation': 4090,
#  '100,000': 75,
#  'cì': 1371,
#  '«': 5150,
#  'te': 4521,
#  'd\x89ûªivoire': 1623,
#  'cocoa': 1154,
#  'communities\x89û\x9d': 1198,
#  'fdbuseurope': 1940,
#  'citi\x89ûªs': 1099,
#  'bobannibaleciti': 803,
#  'building': 889,
#  'sustainable': 4479,
#  'infrastructure': 2544,
#  'enable': 1720,
#  'service': 4186,
#  'unbanked': 4722,
#  'israel': 2634,
#  'new': 3278,
#  'ra': 3809,
#  'discovered': 1533,
#  'pfe\x89ûªs': 3549,
#  'connecticut': 1243,
#  'lab': 2769,
#  'amplifies': 503,
#  'using': 4780,
#  'technology': 4532,
#  'aid': 447,
#  'healthy': 2338,
#  'make': 2961,
#  'sense': 4173,
#  'philanthropy': 3566,
#  'thanks': 4552,
#  'making': 2962,
#  'dnchacon': 1560,
#  'volunteerism': 4851,
#  'beautiful': 702,
#  'way': 4909,
#  'give': 2172,
#  'mexico': 3074,
#  'voluntariadobanamex': 4846,
#  'dannon': 1392,
#  'company': 1205,
#  'nutritionå¨': 3344,
#  'grant': 2219,
#  'supporting': 4468,
#  'nutrition': 3342,
#  'physical': 3576,
#  'ecosystem': 1653,
#  'merapi': 3058,
#  'rehabilitate': 3916,
#  'agricultural': 444,
#  'eruption': 1786,
#  'volcano': 4843,
#  '2010': 151,
#  'china': 1052,
#  'craftwork': 1327,
#  'guizhou-': 2265,
#  'increase': 2515,
#  'artisan': 582,
#  'household': 2426,
#  '30-40': 201,
#  'apac': 535,
#  'chairman': 1008,
#  'peter': 3546,
#  'brabeck': 837,
#  'solid': 4303,
#  'growth': 2249,
#  'all': 466,
#  'margin': 2991,
#  'london': 2903,
#  'south': 4320,
#  'east': 1640,
#  'home': 2408,
#  'highest': 2379,
#  'uk': 4718,
#  'ì¢\x89ââ\x81ò': 5155,
#  'sign': 4233,
#  'supply': 4464,
#  'chain': 1006,
#  'initiativeì¢\x89ââå\x9d': 2555,
#  'foodnavigator': 2026,
#  'institute': 2571,
#  'been': 707,
#  'el': 1677,
#  'centro': 991,
#  'catalìäåán': 966,
#  'de': 1420,
#  'nutriciìäå_n': 3338,
#  'judge': 2707,
#  'weighs': 4936,
#  'fairness': 1907,
#  '590': 254,
#  'mln': 3129,
#  'pact': 3466,
#  'rob': 4029,
#  'insight': 2565,
#  'globe': 2187,
#  'mail': 2954,
#  'ziayusuf': 5095,
#  'streetlineinc': 4418,
#  'example': 1834,
#  'successful': 4443,
#  'urban': 4766,
#  'what': 4959,
#  'possible': 3640,
#  'progressmakers': 3735,
#  'patient': 3511,
#  'safety': 4073,
#  'information': 2543,
#  'tsn': 4681,
#  'member': 3048,
#  'vera': 4808,
#  'rulon': 4051,
#  'announce': 520,
#  "'ve": 29,
#  'reached': 3836,
#  '10yr/': 85,
#  '50bn': 246,
#  'climate': 1125,
#  '3yrs': 217,
#  'early': 1632,
#  'citisustainability': 1092,
#  'scientist': 4126,
#  'found': 2054,
#  'several': 4193,
#  'risk': 4020,
#  'factor': 1896,
#  'could': 1307,
#  'person': 3538,
#  'develop': 1487,
#  'melanoma': 3045,
#  'caroline': 958,
#  'roan': 4028,
#  'encourage': 1725,
#  'dialogue': 1502,
#  'getting': 2158,
#  'older': 3378,
#  'living': 2895,
#  'better': 743,
#  'bdi1': 697,
#  'alibaba': 460,
#  'secures': 4144,
#  '8': 288,
#  'billion': 762,
#  'loan': 2897,
#  'education': 1663,
#  'programme': 3733,
#  'india': 2523,
#  'wwweek': 5052,
#  'csv2011': 1346,
#  'grocery': 2239,
#  'shopping': 4214,
#  'celebrity': 983,
#  'chefartsmith': 1038,
#  'prof': 3727,
#  '``': 322,
#  'need': 3244,
#  'link': 2877,
#  'agriculture': 445,
#  'system': 4489,
#  'holistically': 2406,
#  "''": 6,
#  'spain': 4325,
#  'managed': 2971,
#  'create': 1329,
#  'over': 3439,
#  '150': 110,
#  'opportunity': 3406,
#  'social': 4292,
#  'endvaw': 1732,
#  'randyhy69': 3820,
#  'asked': 590,
#  'fla': 2005,
#  'map': 2986,
#  'published': 3778,
#  'action': 368,
#  'their': 4561,
#  'recos': 3882,
#  'tony': 4614,
#  'coyle': 1323,
#  'pfizer\x89ûªs': 3554,
#  'cti': 1349,
#  'alliance4lupus': 473,
#  'we\x89ûªre': 4953,
#  'co-funding': 1149,
#  'therapy': 4569,
#  'w/lupus': 4873,
#  'p4c2013': 3460,
#  'let\x89ûªs': 2842,
#  'join': 2684,
#  'convergence': 1275,
#  'palais': 3471,
#  'brongniart': 874,
#  'until': 4757,
#  'sept': 4177,
#  '19th': 135,
#  'socialbusiness': 4294,
#  'teamc2015': 4525,
#  'langrenxdh': 2781,
#  'info': 2540,
#  'moveribfan': 3174,
#  'hi': 2373,
#  'reassure': 3851,
#  'ukraine': 4719,
#  'voice': 4841,
#  'beneficiary': 730,
#  'ethnographic': 1803,
#  'sustainability': 4478,
#  'cofco': 1155,
#  'mengniu': 3051,
#  'force': 2035,
#  'accelerate': 341,
#  'fresh': 2077,
#  'dairy': 1380,
#  'product': 3721,
#  "'re": 19,
#  'regeneration': 3911,
#  'haiti': 2287,
#  'coffee': 1157,
#  'industry': 2532,
#  'multi-partner': 3193,
#  'nestlìäå©': 3271,
#  'brabeck-letmathe': 838,
#  "'": 5,
#  'i': 2459,
#  'leave': 2819,
#  'my': 3206,
#  'empire': 1705,
#  'mrjamesashton': 3183,
#  'question': 3801,
#  'reputation': 3960,
#  'italian': 2638,
#  'repubblicait': 3957,
#  'accolade': 349,
#  'latin': 2795,
#  'america': 495,
#  'equity': 1780,
#  'admin': 388,
#  'ghf': 2160,
#  'tracy': 4644,
#  'sienko': 4231,
#  'addressing': 382,
#  'care': 952,
#  'underserved': 4735,
#  'tanzania': 4507,
#  'adele': 383,
#  'gulfo': 2266,
#  'gulfoa': 2267,
#  'receiving': 3860,
#  'springboardent': 4357,
#  'oracle': 3413,
#  'open': 3394,
#  'path': 3508,
#  "'m": 16,
#  'turned': 4692,
#  'business': 896,
#  'ama': 489,
#  'recognizes': 3870,
#  'excellence': 1835,
#  'foodbankhv': 2021,
#  'pic': 3578,
#  'tsn\x89ûªs': 4683,
#  'jon': 2689,
#  'milton': 3110,
#  'pride': 3699,
#  'his': 2393,
#  'pfizer_news': 3552,
#  'curiosity': 1355,
#  'desire': 1478,
#  'status': 4391,
#  'quo': 3805,
#  'shesthefirst': 4210,
#  'collaborative': 1166,
#  'effort': 1671,
#  'proportion': 3750,
#  'aged': 430,
#  '60+': 263,
#  'globally': 2185,
#  'growing': 2246,
#  'faster': 1928,
#  'than': 4550,
#  'any': 533,
#  'other': 3422,
#  'necessitating': 3243,
#  'preventive': 3693,
#  'behavior': 713,
#  'wsj': 5043,
#  'steve': 4400,
#  'still': 4402,
#  'become': 704,
#  'philanthropist': 3565,
#  'optimism': 3409,
#  'received': 3858,
#  'stockholm': 4406,
#  'commitment': 1186,
#  'oct': 3363,
#  'adhd': 385,
#  'did': 1504,
#  'know': 2750,
#  'affect': 411,
#  '5m': 255,
#  'visit': 4829,
#  'caregiver': 954,
#  'creates': 1331,
#  'nigeria': 3293,
#  'allafrica': 468,
#  'fair': 1904,
#  'labor': 2770,
#  'association': 602,
#  'identified': 2471,
#  '11': 87,
#  'recommendation': 3873,
#  'tackle': 4492,
#  'labour': 2771,
#  'emerging': 1697,
#  'market': 2996,
#  'approx': 555,
#  '92': 305,
#  'bil': 760,
#  'annually': 525,
#  'failing': 1900,
#  '2': 138,
#  'educate': 1661,
#  'girl': 2171,
#  'empowerweb': 1718,
#  'eforeducation': 1672,
#  'goldman': 2202,
#  'volcker': 4844,
#  'workaround': 5011,
#  'buyout': 902,
#  'k.p': 2719,
#  'attracting': 616,
#  'developping': 1491,
#  'retaining': 3981,
#  'talent': 4499,
#  'procurement': 3717,
#  'organization': 3416,
#  'priority': 3704,
#  'nestleir': 3267,
#  'publishing': 3780,
#  'innovating': 2558,
#  'long-term': 2906,
#  'cash': 962,
#  'flow': 2010,
#  'which': 4965,
#  'ken': 2729,
#  'frazier': 2067,
#  'squawkcnbc': 4361,
#  'young': 5083,
#  'born': 823,
#  'small': 4276,
#  'gestational': 2154,
#  'age': 429,
#  'meet': 3043,
#  'primary': 3700,
#  'endpoint': 1731,
#  'left': 2825,
#  'gift': 2167,
#  'last': 2789,
#  'minute': 3121,
#  'don\x89ûªt': 1579,
#  'same': 4084,
#  'quit': 3802,
#  'smoking': 4282,
#  'city': 1104,
#  'continue': 1264,
#  'deliver': 1454,
#  'uscmwinter14': 4773,
#  'danonino': 1405,
#  'launched': 2800,
#  '7': 276,
#  'dino': 1520,
#  'bottle': 830,
#  'special': 4333,
#  'nurture': 3336,
#  'kid\x89ûªs': 2741,
#  'autonomy': 630,
#  'clarification': 1111,
#  'scope': 4129,
#  'voluntary': 4848,
#  'recall': 3855,
#  'france': 2062,
#  'alyssa_milano': 485,
#  'win': 4983,
#  'citizenship': 1098,
#  '\x89ûïhaving': 5120,
#  'phone': 3570,
#  'having': 2318,
#  'palm': 3473,
#  'hand-\x89û\x9d': 2294,
#  'ceo': 993,
#  'mike': 3099,
#  'mwc2014': 3205,
#  'keynote': 2736,
#  'denisepiercy': 1462,
#  'committed': 1188,
#  'address': 381,
#  'please': 3603,
#  'tami': 4503,
#  'evans': 1814,
#  'citiì¢\x89ââ\x89ã¢s': 1103,
#  'money2': 3145,
#  'wa': 4883,
#  'named': 3218,
#  'bronze': 876,
#  'winner': 4986,
#  'edisonawards': 1656,
#  'week': 4929,
#  'san': 4086,
#  'francisco': 2064,
#  'tim': 4598,
#  'hortons': 2417,
#  'agitates': 437,
#  'buyback': 899,
#  'canadian': 937,
#  'coffee-and-donut': 1158,
#  'hacker': 2283,
#  'threaten': 4586,
#  'government': 2208,
#  'offline': 3373,
#  'tuesday': 4686,
#  'begin': 710,
#  'round': 4040,
#  'cut': 1361,
#  'source': 4318,
#  'clear': 1120,
#  'towards': 4634,
#  'realising': 3848,
#  'world': 5022,
#  'leader': 2811,
#  'wellness': 4943,
#  'pledged': 3608,
#  'gt': 2254,
#  '105': 82,
#  'initiate': 2551,
#  '30': 200,
#  '20': 141,
#  "'stars": 24,
#  'isle': 2630,
#  'man': 2969,
#  'raise': 3815,
#  'money': 3144,
#  'rebecca': 3852,
#  'house': 2425,
#  'island\x89ûªs': 2629,
#  'children\x89ûªs': 1049,
#  'hospice': 2418,
#  'thedoctors': 4559,
#  'freda': 2068,
#  'lewis-hall': 2849,
#  'md': 3025,
#  'stress': 4423,
#  'chile': 1050,
#  'opening': 3396,
#  'factory': 1897,
#  'yolande': 5079,
#  'morris': 3161,
#  'rwanda': 4060,
#  ...}

# %% [markdown]
# ### Step 3: Predict on test data
# * Transform (no fitting) the test data with the same CountVectorizer and TfidfTransformer
# * Predict labels on these tfidf values.

# %%
# Predict test labels
X_test_counts = vect.transform(X_test)
X_test_tfidf = tfidf.transform(X_test_counts)
y_pred = clf.predict(X_test_tfidf)

# display results
display_results(y_test, y_pred)
# Out:
# Labels: ['Action' 'Dialogue' 'Information']
# Confusion Matrix:
#  [[103   0  34]
#  [  1  40  11]
#  [  3   0 601]]
# Accuracy: 0.9382093316519546

# %% [markdown]
# ### Step 4: Display results
# Display a confusion matrix and accuracy score based on the model's predictions.

# %%
labels = np.unique(y_pred)
confusion_mat = confusion_matrix(y_test, y_pred, labels=labels)
accuracy = (y_pred == y_test).mean()

print("Labels:", labels)
print("Confusion Matrix:\n", confusion_mat)
print("Accuracy:", accuracy)
# Out:
# Labels: ['Action' 'Dialogue' 'Information']
# Confusion Matrix:
#  [[102   0  35]
#  [  3  39  10]
#  [  5   1 598]]
# Accuracy: 0.9319041614123581

# %% [markdown]
# # Final Step: Refactor
# Organize these steps into the following functions.

# %%
def main():
    X, y = load_data()
    X_train, X_test, y_train, y_test = train_test_split(X, y)

    vect = CountVectorizer(tokenizer=tokenize)
    tfidf = TfidfTransformer()
    clf = RandomForestClassifier()

    # train classifier
    X_train_counts = vect.fit_transform(X_train)
    X_train_tfidf = tfidf.fit_transform(X_train_counts)
    clf.fit(X_train_tfidf, y_train)

    # predict on test data
    X_test_counts = vect.transform(X_test)
    X_test_tfidf = tfidf.transform(X_test_counts)
    y_pred = clf.predict(X_test_tfidf)

    # display results
    display_results(y_test, y_pred)


main()
# Out:
# Labels: ['Action' 'Dialogue' 'Information']
# Confusion Matrix:
#  [[ 75   1  29]
#  [  1  19   5]
#  [  2   0 469]]
# Accuracy: 0.9367720465890182

# %%
# run program
main()
# Out:
# Labels: ['Action' 'Dialogue' 'Information']
# Confusion Matrix:
#  [[ 75   1  34]
#  [  0  32   0]
#  [  6   2 451]]
# Accuracy: 0.9284525790349417
